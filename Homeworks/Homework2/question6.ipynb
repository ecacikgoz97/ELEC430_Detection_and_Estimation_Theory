# %%
# Imports
using Random, Statistics, Plots, Printf
Random.seed!(430);

# %%
# Part (a)
N = 10000;
Xₙ = randn(2, 1);
μₓ = [0.5; 0.3];
Cₓ = [1 0.6; 0.6 sqrt(2)];

# %%
# 2-dimensional Gaussian vector
X = Cₓ * Xₙ + μₓ
# Out:
# 2×1 Matrix{Float64}:
#  1.4624980249801924
#  1.5351690363820665

# %%
# Part (b)
# Generate 10000 vector with related parameters
function generate(matrix, μₓ, n)
    samples = zeros(N, 2)
    for i in 1:n
        X = randn(2, 1);
        X = sqrt(matrix) * X + μₓ;
        samples[i, :] = X;
    end
    return samples
end
# Out:
# generate (generic function with 1 method)

# %%
# Plot generated samples
samples = generate(Cₓ, μₓ, N)
X₁, X₂ = samples[:, 1], samples[:, 2];
plot(X₁, X₂, seriestype = :scatter, title = "Scatter Plot")

# %%
# Part (c)
∑ = zeros(2,2);
for i in 1:N
    ∑ += samples[i, :]*samples[i, :]'
end
println("Answer of part (c) for $N samples: ")
Sₓ =  ∑/N
# Out:
# Answer of part (c) for 10000 samples:
# 2×2 Matrix{Float64}:
#  1.25953  0.72561
#  0.72561  1.49158

# %%
# When we increase "N", convergence will be [1.25 0.75; 0.75 1.504] matrix
println("Convergence limit matrix:")
convergence = Cₓ + μₓ*μₓ'
# Out:
# Convergence limit matrix:
# 2×2 Matrix{Float64}:
#  1.25  0.75
#  0.75  1.50421
